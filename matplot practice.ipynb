# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x=[1,2,3]
y=[1,4,9]
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3]
y=[1,4,9]
plt.plot(x,y)
plt.title('test graph')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x=[1,2,3]
y=[1,4,9]
z=[10,5,0]
plt.plot(x,y)
plt.plot(x,z)
plt.title('test graph')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x=[1,2,3]
y=[1,4,9]
z=[10,5,0]
plt.plot(x,y)
plt.plot(x,z)
plt.title('test graph')

plt.legend('this is y','this is z')

plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Legend does not support 't' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Legend does not support 'h' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Legend does not support 'i' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Legend does not support 's' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Legend does not support ' ' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Legend does not support 'y' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists

# %%
sample_data=pd.read_csv('sample_data (2).csv')
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
plt.plot(sample_data.column_a,sample_data.column_c)
plt.show()

# %%
plt.plot(sample_data.column_a,sample_data.column_c)
plt.xlabel('sales')
plt.ylabel('products')
plt.show()

# %%
plt.plot(sample_data.column_a,sample_data.column_c)
plt.xlabel('sales')
plt.ylabel('products')
plt.title('analasis of comany sales performence for the quater')
plt.show()

# %%
plt.plot(sample_data.column_a,sample_data.column_c)
plt.xlabel('sales')
plt.ylabel('products')
plt.title('analasis of comany sales performence for the quater')
plt.legend('this is x')
plt.show()
