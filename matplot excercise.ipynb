# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('countries (2).csv')
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
#req:compare the papulation of us and china

# %%
data.country=='United States'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
us=data[data.country=='United States']

# %%
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
plt.plot(us.year,us.population/10**6)
plt.show()

# %%
China=data[data.country=='China']

# %%
China
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(China.year,China.population/10**6)
plt.show()

# %%
plt.plot(us.year,us.population/10**6)
plt.plot(China.year,China.population/10**6)
plt.show()

# %%
plt.plot(us.year,us.population/10**6)
plt.plot(China.year,China.population/10**6)
plt.title('comparing papulation of a countrys based on year')
plt.legend('China')
plt.legend('united states')
plt.xlabel('year')
plt.ylabel('papulation')
plt.show()

# %%
Austria=data[data.country=='Austria']

# %%
Austria
# Out:
#     country  year  population
# 72  Austria  1952     6927772
# 73  Austria  1957     6965860
# 74  Austria  1962     7129864
# 75  Austria  1967     7376998
# 76  Austria  1972     7544201
# 77  Austria  1977     7568430
# 78  Austria  1982     7574613
# 79  Austria  1987     7578903
# 80  Austria  1992     7914969
# 81  Austria  1997     8069876
# 82  Austria  2002     8148312
# 83  Austria  2007     8199783

# %%
Venezuela=data[data.country=='Venezuela']

# %%
Venezuela
# Out:
#         country  year  population
# 1632  Venezuela  1952     5439568
# 1633  Venezuela  1957     6702668
# 1634  Venezuela  1962     8143375
# 1635  Venezuela  1967     9709552
# 1636  Venezuela  1972    11515649
# 1637  Venezuela  1977    13503563
# 1638  Venezuela  1982    15620766
# 1639  Venezuela  1987    17910182
# 1640  Venezuela  1992    20265563
# 1641  Venezuela  1997    22374398
# 1642  Venezuela  2002    24287670
# 1643  Venezuela  2007    26084662

# %%
plt.plot(Austria.year,Austria.population/10**6)
plt.plot(Venezuela.year,Venezuela.population/10**6)
plt.title('comparing papulation of a countrys based on year')
plt.legend('Austria')
plt.legend('Venezuela')
plt.xlabel('year')
plt.ylabel('papulation')
plt.show()

# %%
sl=data[data.country=='Switzerland']

# %%
sl
# Out:
#           country  year  population
# 1476  Switzerland  1952     4815000
# 1477  Switzerland  1957     5126000
# 1478  Switzerland  1962     5666000
# 1479  Switzerland  1967     6063000
# 1480  Switzerland  1972     6401400
# 1481  Switzerland  1977     6316424
# 1482  Switzerland  1982     6468126
# 1483  Switzerland  1987     6649942
# 1484  Switzerland  1992     6995447
# 1485  Switzerland  1997     7193761
# 1486  Switzerland  2002     7361757
# 1487  Switzerland  2007     7554661

# %%
Syria=data[data.country=='Syria']

# %%
Syria
# Out:
#      country  year  population
# 1488   Syria  1952     3661549
# 1489   Syria  1957     4149908
# 1490   Syria  1962     4834621
# 1491   Syria  1967     5680812
# 1492   Syria  1972     6701172
# 1493   Syria  1977     7932503
# 1494   Syria  1982     9410494
# 1495   Syria  1987    11242847
# 1496   Syria  1992    13219062
# 1497   Syria  1997    15081016
# 1498   Syria  2002    17155814
# 1499   Syria  2007    19314747

# %%
plt.plot(sl.year,sl.population/10**6)
plt.plot(Syria.year,Syria.population/10**6)
plt.title('comparing papulation of a countrys based on year')
plt.legend('sl')
plt.legend('Syria')
plt.xlabel('year')
plt.ylabel('papulation')
plt.show()

# %%
Nigeria=data[data.country=='Nigeria']

# %%
Nigeria
# Out:
#       country  year  population
# 1128  Nigeria  1952    33119096
# 1129  Nigeria  1957    37173340
# 1130  Nigeria  1962    41871351
# 1131  Nigeria  1967    47287752
# 1132  Nigeria  1972    53740085
# 1133  Nigeria  1977    62209173
# 1134  Nigeria  1982    73039376
# 1135  Nigeria  1987    81551520
# 1136  Nigeria  1992    93364244
# 1137  Nigeria  1997   106207839
# 1138  Nigeria  2002   119901274
# 1139  Nigeria  2007   135031164

# %%
Myanmar=data[data.country=='Myanmar']

# %%
Myanmar
# Out:
#       country  year  population
# 1044  Myanmar  1952    20092996
# 1045  Myanmar  1957    21731844
# 1046  Myanmar  1962    23634436
# 1047  Myanmar  1967    25870271
# 1048  Myanmar  1972    28466390
# 1049  Myanmar  1977    31528087
# 1050  Myanmar  1982    34680442
# 1051  Myanmar  1987    38028578
# 1052  Myanmar  1992    40546538
# 1053  Myanmar  1997    43247867
# 1054  Myanmar  2002    45598081
# 1055  Myanmar  2007    47761980

# %%
plt.plot(Nigeria.year,Nigeria.population/10**6)
plt.plot(Myanmar.year,Myanmar.population/10**6)
plt.title('comparing papulation of a countrys based on year')
plt.legend('Nigeria')
plt.legend('Myanmar')
plt.xlabel('year')
plt.ylabel('papulation')
plt.show()

# %%
Japan=data[data.country=='Japan']

# %%
Japan
# Out:
#     country  year  population
# 792   Japan  1952    86459025
# 793   Japan  1957    91563009
# 794   Japan  1962    95831757
# 795   Japan  1967   100825279
# 796   Japan  1972   107188273
# 797   Japan  1977   113872473
# 798   Japan  1982   118454974
# 799   Japan  1987   122091325
# 800   Japan  1992   124329269
# 801   Japan  1997   125956499
# 802   Japan  2002   127065841
# 803   Japan  2007   127467972

# %%
Italy=data[data.country=='Italy']

# %%
Italy
# Out:
#     country  year  population
# 768   Italy  1952    47666000
# 769   Italy  1957    49182000
# 770   Italy  1962    50843200
# 771   Italy  1967    52667100
# 772   Italy  1972    54365564
# 773   Italy  1977    56059245
# 774   Italy  1982    56535636
# 775   Italy  1987    56729703
# 776   Italy  1992    56840847
# 777   Italy  1997    57479469
# 778   Italy  2002    57926999
# 779   Italy  2007    58147733

# %%
plt.plot(Japan.year,Japan.population/10**6)
plt.plot(Italy.year,Italy.population/10**6)
plt.title('comparing papulation of a countrys based on year')
plt.legend('Japan')
plt.legend('Italy')
plt.xlabel('year')
plt.ylabel('papulation')
plt.show()
