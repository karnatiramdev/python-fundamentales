# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('artwork_data.csv')
print(df)
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=10)
print(df)
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=10,index_col='id')#here the default index is replaced by column id
print(df)
# Out:
#      accession_number          artist artistRole  artistId  \
# id
# 1035           A00001   Blake, Robert     artist        38
# 1036           A00002   Blake, Robert     artist        38
# 1037           A00003   Blake, Robert     artist        38
# 1038           A00004   Blake, Robert     artist        38
# 1039           A00005  Blake, William     artist        39
# 1040           A00006  Blake, William     artist        39
# 1041           A00007  Blake, William     artist        39
# 1042           A00008  Blake, William     artist        39
# 1043           A00009  Blake, William     artist        39
# 1044           A00010  Blake, William     artist        39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=10,index_col='id',usecols=['id','artist','artistRole','artistId' ])
print(df)
# Out:
#               artist artistRole  artistId
# id
# 1035   Blake, Robert     artist        38
# 1036   Blake, Robert     artist        38
# 1037   Blake, Robert     artist        38
# 1038   Blake, Robert     artist        38
# 1039  Blake, William     artist        39
# 1040  Blake, William     artist        39
# 1041  Blake, William     artist        39
# 1042  Blake, William     artist        39
# 1043  Blake, William     artist        39
# 1044  Blake, William     artist        39

# %%
cols_to_use=['id','artist','title','medium','year','acquisitionYear','height','width','units']
df=pd.read_csv('artwork_data.csv',nrows=10,index_col=cols_to_use)
print(df)
# Out:
#                                                                                                                                                                     accession_number  \
# id   artist         title                                              medium                                             year   acquisitionYear height width units
# 1035 Blake, Robert  A Figure Bowing before a Seated Old Man with hi... Watercolour, ink, chalk and graphite on paper. ... NaN    1922            419    394   mm              A00001
# 1036 Blake, Robert  Two Drawings of Frightened Figures, Probably fo... Graphite on paper                                  NaN    1922            213    311   mm              A00002
# 1037 Blake, Robert  The Preaching of Warning. Verso: An Old Man Ent... Graphite on paper. Verso: graphite on paper        1785.0 1922            467    343   mm              A00003
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=10,index_col='id',usecols=cols_to_use)
print(df)
# Out:
#               artist                                              title  \
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 1040  Blake, William      Ciampolo the Barrator Tormented by the Devils
# 1041  Blake, William                        The Baffled Devils Fighting
# 1042  Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 1043  Blake, William                 The Serpent Attacking Buoso Donati
# 1044  Blake, William                 The Pit of Disease: The Falsifiers
#
#                                                  medium    year  \
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN
# ...

# %%
df=pd.read_csv('artwork_data.csv',nrows=10,usecols=cols_to_use)
print(df)
# Out:
#      id          artist                                              title  \
# 0  1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1  1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2  1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3  1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 5  1040  Blake, William      Ciampolo the Barrator Tormented by the Devils
# 6  1041  Blake, William                        The Baffled Devils Fighting
# 7  1042  Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 8  1043  Blake, William                 The Serpent Attacking Buoso Donati
# 9  1044  Blake, William                 The Pit of Disease: The Falsifiers
#
#                                               medium    year  acquisitionYear  \
# ...

# %%
#how many distctinct artist are there in the dataset

# %%
df=pd.read_csv('artwork_data.csv')
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# ...

# %%
artists=df['artist']

# %%
pd.unique(artists)
# Out:
# array(['Blake, Robert', 'Blake, William', 'Richmond, George', ...,
#        'Sterne, Hedda', 'P-Orridge, Genesis', 'Brunias, Agostino'],
#       dtype=object)

# %%
len(pd.unique(artists))
# Out:
# 3336

# %%
#how many artworks by Brunias, Agostino are there

# %%
s=df['artist']=='Brunias, Agostino'

# %%
s.value_counts()
# Out:
# False    69200
# True         1
# Name: artist, dtype: int64

# %%
s=df['artist']=='Blake, William'

# %%
s.value_counts()
# Out:
# False    69021
# True       180
# Name: artist, dtype: int64

# %%
#introduction to loc and iloc

# %%
#syntax:df.loc[rowindex,colindex]

# %%
df.loc[1035,'artist']
# Out:
# 'Beerbohm, Sir Max'

# %%
df.loc[1035,'artist']
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.iloc[100:300,[0,1,4,5]]#0,1,4,5 are columns name
# Out:
#         id accession_number  artistId  \
# 100   1737           A00101        68
# 101   1738           A00102        68
# 102   1739           A00103        68
# 103  20231           A00104        68
# 104   1740           A00105        68
# ..     ...              ...       ...
# 295   7329           A00299       300
# 296   7330           A00300       300
# 297   7331           A00301       300
# 298   7332           A00302       300
# 299   7333           A00303       300
#
#                                                  title
# 100                                     Head of a Girl
# 101                                       Figure Study
# 102  Study of the Head of a Female Attendant for ‘T...
# 103  Study of Iseult for ‘The Marriage of Sir Trist...
# 104             Composition Study for ‘Clerk Saunders’
# ..                                                 ...
# 295                                  [title not known]
# 296                                  [title not known]
# ...

# %%
area=height*width

# %%
df['width'].sort_values().head()
# Out:
# 62198           (1):
# 68540    (diameter):
# 2427         (each):
# 54196        (each):
# 67796       (image):
# Name: width, dtype: object

# %%
df['width'].sort_values().tail()
# Out:
# 69188    NaN
# 69190    NaN
# 69191    NaN
# 69193    NaN
# 69199    NaN
# Name: width, dtype: object

# %%
a=pd.to_numeric(df['height'],errors='coerce')

# %%
b=pd.to_numeric(df['width'],errors='coerce')

# %%
area=a*b
area
# Out:
# 0        165086.0
# 1         66243.0
# 2        160181.0
# 3        125292.0
# 4         81405.0
#            ...
# 69196     93025.0
# 69197     93025.0
# 69198    108450.0
# 69199         NaN
# 69200    335280.0
# Length: 69201, dtype: float64

# %%
area.max()
# Out:
# 132462000.0
